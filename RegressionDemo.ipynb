# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    "Area":[1000,1500,2000,2200,2400,2500],
    "Price":[30,45,60,64,66,69]
}
df=pd.DataFrame(data)
df
# Out:
#    Area  Price
# 0  1000     30
# 1  1500     45
# 2  2000     60
# 3  2200     64
# 4  2400     66
# 5  2500     69

# %%
X=df[["Area"]]#for 2d
Y=df["Price"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
print("Slope:",model.coef_[0])
print("Intercept:",model.intercept_)
# Out:
# Slope: 0.025976095617529883
# Intercept: 5.446215139442224

# %%
prediction=model.predict([[1800]])
print("Preicted price:",prediction[0],"Lakhs")
# Out:
# Preicted price: 52.20318725099601 Lakhs
# C:\Users\Suha Ali\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[1650]])
print("Preicted price:",prediction[0],"Lakhs")
# Out:
# Preicted price: 48.30677290836653 Lakhs
# C:\Users\Suha Ali\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_area=[[1000],[1500],[2000]]
predictions=model.predict(new_area)
print(predictions)
# Out:
# [31.42231076 44.41035857 57.39840637]
# C:\Users\Suha Ali\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#plot Regression Line
plt.figure(figsize=(7,5))
plt.scatter(X, Y, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(X,
         model.predict(X),
         color='red',
         linewidth=2,
         label='Regression Line')

# Add labels and title
plt.xlabel("Area(sq ft)")
plt.ylabel("Price(lakhs)")
plt.title("Simple Linear Regression")

# Show legend
plt.legend()

# Display the graph
plt.show()
