# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('IPL_Batter.csv')
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
#1
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# ...

# %%
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %%
#2 display the  last five rows
df.tail()
# Out:
#           Player Name Team  Runs  Matches  Inn  No  HS   AVG  BF     SR  100s  \
# 151     Khaleel Ahmed  CSK     1       14    2   2  1*     -   2  50.00     0
# 152      Mohit Sharma   DC     1        8    2   1  1*  1.00   3  33.33     0
# 153  Donovan Ferreira   DC     1        1    1   0   1  1.00   3  33.33     0
# 154     Digvesh Singh  LSG     1       13    2   1   1  1.00   3  33.33     0
# 155    Manoj Bhandage  RCB     1        1    1   0   1  1.00   4  25.00     0
#
#      50s  4s  6s
# 151    0   0   0
# 152    0   0   0
# 153    0   0   0
# 154    0   0   0
# 155    0   0   0

# %%
#find the number of rows and columns
df.shape
# Out:
# (156, 14)

# %%
#4display column names
df.columns
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %%
#5display data types
df.dtypes
# Out:
# Player Name     object
# Team            object
# Runs             int64
# Matches          int64
# Inn              int64
# No               int64
# HS              object
# AVG             object
# BF               int64
# SR             float64
# 100s             int64
# 50s              int64
# 4s               int64
# 6s               int64
# dtype: object

# %%
#7 generate summary statistics
df.describe()
# Out:
#              Runs     Matches         Inn          No          BF          SR  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   161.320513    9.865385    7.153846    1.634615  105.673077  134.394103
# std    180.352772    4.757455    4.810142    1.658163  112.191838   57.237148
# min      1.000000    1.000000    1.000000    0.000000    1.000000   25.000000
# 25%     10.750000    6.000000    2.750000    0.000000   12.000000  100.000000
# 50%     93.500000   11.000000    6.000000    1.000000   63.500000  140.005000
# 75%    254.250000   14.000000   12.000000    3.000000  164.750000  162.707500
# max    759.000000   17.000000   17.000000    7.000000  486.000000  400.000000
#
#              100s         50s          4s          6s
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.057692    0.916667   14.391026    8.294872
# std      0.233912    1.590124   17.778774    9.515500
# ...

# %%
#8 missing values 
df.isnull().sum()
# Out:
# Player Name    0
# Team           0
# Runs           0
# Matches        0
# Inn            0
# No             0
# HS             0
# AVG            0
# BF             0
# SR             0
# 100s           0
# 50s            0
# 4s             0
# 6s             0
# dtype: int64

# %%
#display only the name of the columns
df["Player Name"]
# Out:
# 0          Sai Sudharsan
# 1      Surya Kumar Yadav
# 2            Virat Kohli
# 3           Shubman Gill
# 4         Mitchell Marsh
#              ...
# 151        Khaleel Ahmed
# 152         Mohit Sharma
# 153     Donovan Ferreira
# 154        Digvesh Singh
# 155       Manoj Bhandage
# Name: Player Name, Length: 156, dtype: object

# %%
#10 display name,runs and matches columns
df[["Player Name","Runs","Matches"]]
# Out:
#            Player Name  Runs  Matches
# 0        Sai Sudharsan   759       15
# 1    Surya Kumar Yadav   717       16
# 2          Virat Kohli   657       15
# 3         Shubman Gill   650       15
# 4       Mitchell Marsh   627       13
# ..                 ...   ...      ...
# 151      Khaleel Ahmed     1       14
# 152       Mohit Sharma     1        8
# 153   Donovan Ferreira     1        1
# 154      Digvesh Singh     1       13
# 155     Manoj Bhandage     1        1
#
# [156 rows x 3 columns]

# %%
#11 Find names with more runs
df[df["Runs"]>100]
# Out:
#           Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 70      Vijay Shankar  CSK   118        6    5   2   69*  39.33   91  129.67
# 71         Sam Curran  CSK   114        5    5   0    88  22.80   84  135.71
# 72   Liam Livingstone  RCB   112       10    8   1    54  16.00   84  133.33
# 73      Krunal Pandya  RCB   109       15    7   1   73*  18.17   86  126.74
# 74      Shubham Dubey   RR   106        9    8   4   34*  26.50   66  160.60
#
#     100s  50s  4s  6s
# ...

# %%
#12 players from csk
df[df["Team"] == "CSK"]
# Out:
#              Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 22           Shivam Dube  CSK   357       14   14   3   50  32.45  270
# 30       Ravindra Jadeja  CSK   301       14   14   5  77*  33.44  222
# 43          Ayush Mhatre  CSK   240        7    7   0   94  34.29  127
# 47         Dewald Brevis  CSK   225        6    6   0   57  37.50  125
# 54              MS Dhoni  CSK   196       14   13   5  30*  24.50  145
# 55       Rachin Ravindra  CSK   191        8    8   1  65*  27.29  149
# 62          Devon Conway  CSK   156        6    6   0   69  26.00  119
# 68       Ruturaj Gaikwad  CSK   122        5    5   0   63  24.40   81
# 70         Vijay Shankar  CSK   118        6    5   2  69*  39.33   91
# 71            Sam Curran  CSK   114        5    5   0   88  22.80   84
# 83         Shaik Rasheed  CSK    71        5    5   0   27  14.20   63
# 85           Urvil Patel  CSK    68        3    3   0   37  22.67   32
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
#13find the player with more number of matches 
df[df["Matches"]>=15]
# Out:
#            Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0        Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1    Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2          Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3         Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 5         Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 7    Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 12       Priyansh Arya  PBKS   475       17   17   0   103  27.94  265
# 15        Rohit Sharma    MI   418       15   15   1    81  29.86  280
# 21       Nehal Wadhera  PBKS   369       16   15   3    70  30.75  253
# 24      Shashank Singh  PBKS   350       17   14   7   61*  50.00  228
# 25       N Tilak Varma    MI   343       16   13   2    59  31.18  248
# 28       Rajat Patidar   RCB   312       15   14   1    64  24.00  217
# ...

# %%
#14display inn more than 10
df[df["Inn"]>= 10]
# Out:
#              Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1      Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2            Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3           Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4         Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 5           Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 6       Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350
# 7      Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 8              K L Rahul    DC   539       13   13   3  112*  53.90  360
# 9            Jos Buttler    GT   538       14   13   4   97*  59.78  330
# 10       Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267
# 11      Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# ...

# %%
#15display player with 100s
df[df["100s"] == 1]
# Out:
#             Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0         Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 4        Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 8             K L Rahul    DC   539       13   13   3  112*  53.90  360
# 11     Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# 12        Priyansh Arya  PBKS   475       17   17   0   103  27.94  265
# 14      Abhishek Sharma   SRH   439       14   13   0   141  33.77  227
# 23         Ishan Kishan   SRH   354       14   13   3  106*  35.40  232
# 36         Rishabh Pant   LSG   269       14   13   2  118*  24.45  202
# 39  Vaibhav Suryavanshi    RR   252        7    7   0   101  36.00  122
#
#         SR  100s  50s  4s  6s
# 0   156.17     1    6  88  21
# 4   163.70     1    6  56  37
# 8   149.72     1    3  52  21
# 11  172.69     1    1  42  25
# 12  179.24     1    2  55  25
# 14  193.39     1    2  46  28
# ...

# %%
#16total count of the player
len(df)
# Out:
# 156

# %%
#17 count of team player SRH
(df["Team"]== "SRH").sum()
# Out:
# np.int64(14)

# %%
#18 count of team player KKR
(df["Team"]== "KKR").sum()
# Out:
# np.int64(15)

# %%
#19 max runs
df["Runs"].max()
# Out:
# 759

# %%
#20 min runs
df["Runs"].min()
# Out:
# 1

# %%
#21 average runs
df["Runs"].mean()
# Out:
# np.float64(161.32051282051282)

# %%
#22 median 
df["Runs"].median()
# Out:
# 93.5

# %%
#23highest runs made by the player
df[df["Runs"]==df["Runs"].max()]
# Out:
#      Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  100s  \
# 0  Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17     1
#
#    50s  4s  6s
# 0    6  88  21

# %%
#24lowest runs made by the player
df[df["Runs"]==df["Runs"].min()]
# Out:
#                   Player Name Team  Runs  Matches  Inn  No  HS   AVG  BF  \
# 148       Varun Chakaravarthy  KKR     1       13    1   1  1*     -   1
# 149  V Satyanarayana Penmetsa   MI     1        2    1   1  1*     -   1
# 150               Karn Sharma   MI     1        6    1   1  1*     -   1
# 151             Khaleel Ahmed  CSK     1       14    2   2  1*     -   2
# 152              Mohit Sharma   DC     1        8    2   1  1*  1.00   3
# 153          Donovan Ferreira   DC     1        1    1   0   1  1.00   3
# 154             Digvesh Singh  LSG     1       13    2   1   1  1.00   3
# 155            Manoj Bhandage  RCB     1        1    1   0   1  1.00   4
#
#          SR  100s  50s  4s  6s
# 148  100.00     0    0   0   0
# 149  100.00     0    0   0   0
# 150  100.00     0    0   0   0
# 151   50.00     0    0   0   0
# 152   33.33     0    0   0   0
# 153   33.33     0    0   0   0
# 154   33.33     0    0   0   0
# 155   25.00     0    0   0   0

# %%
#25player having bf less than 10
df[df["BF"]<=10]
# Out:
#                   Player Name  Team  Runs  Matches  Inn  No   HS    AVG  BF  \
# 105              Kusal Mendis    GT    20        1    1   0   20  20.00  10
# 109             Jamie Overton   CSK    15        3    2   2  11*      -   7
# 113             Atharva Taide   SRH    13        1    1   0   13  13.00   9
# 117            Mohammad Shami   SRH    10        9    4   3   6*  10.00  10
# 120             Kagiso Rabada    GT     9        4    2   1   7*   9.00   8
# 121             Shahbaz Ahmed   LSG     9        3    1   0    9   9.00   8
# 124             Kwena Maphaka    RR     8        2    1   1   8*      -   2
# 125            Raj Angad Bawa    MI     8        3    1   1   8*      -   4
# 126          Tushar Deshpande    RR     7       10    4   3    3   7.00   8
# 129                Akash Deep   LSG     6        6    2   1   6*   6.00   2
# 130            Sandeep Sharma    RR     6       10    1   1   6*      -   5
# ...

# %%
#26 sort according to the inns
df.sort_values(by="Inn")
# Out:
#            Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 155     Manoj Bhandage   RCB     1        1    1   0     1   1.00    4
# 102    Sediqullah Atal    DC    22        1    1   0    22  22.00   16
# 105       Kusal Mendis    GT    20        1    1   0    20  20.00   10
# 111   Matthew Breetzke   LSG    14        1    1   0    14  14.00   12
# 113      Atharva Taide   SRH    13        1    1   0    13  13.00    9
# ..                 ...   ...   ...      ...  ...  ..   ...    ...  ...
# 0        Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1    Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 12       Priyansh Arya  PBKS   475       17   17   0   103  27.94  265
# 7    Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 5         Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
#
#          SR  100s  50s  4s  6s
# 155   25.00     0    0   0   0
# 102  137.50     0    0   0   2
# ...

# %%
#27 player with more number of matches and 100s
df[(df["Matches"]>= 15 ) & (df["100s"]==1)]
# Out:
#       Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0   Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 12  Priyansh Arya  PBKS   475       17   17   0   103  27.94  265  179.24
#
#     100s  50s  4s  6s
# 0      1    6  88  21
# 12     1    2  55  25

# %%
#df.sort_values(by="Inn") in descending
df.sort_values(by="Inn",ascending=False)
# Out:
#            Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 12       Priyansh Arya  PBKS   475       17   17   0  103  27.94  265  179.24
# 7    Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342  160.52
# 5         Shreyas Iyer  PBKS   604       17   17   5  97*  50.33  345  175.07
# 1    Surya Kumar Yadav    MI   717       16   16   5  73*  65.18  427  167.91
# 21       Nehal Wadhera  PBKS   369       16   15   3   70  30.75  253  145.84
# ..                 ...   ...   ...      ...  ...  ..  ...    ...  ...     ...
# 105       Kusal Mendis    GT    20        1    1   0   20  20.00   10  200.00
# 116    Xavier Bartlett  PBKS    11        4    1   0   11  11.00   15   73.33
# 102    Sediqullah Atal    DC    22        1    1   0   22  22.00   16  137.50
# 133      Rovman Powell   KKR     5        2    1   0    5   5.00    5  100.00
# 155     Manoj Bhandage   RCB     1        1    1   0    1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
#29 TOP 2-Player
df.nlargest(2,"Matches")
# Out:
#          Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 5       Shreyas Iyer  PBKS   604       17   17   5  97*  50.33  345  175.07
# 7  Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342  160.52
#
#    100s  50s  4s  6s
# 5     0    6  43  39
# 7     0    4  56  30

# %%
#30 bottom 2-Player
df.nsmallest(2,"Matches")
# Out:
#          Player Name Team  Runs  Matches  Inn  No  HS    AVG  BF     SR  100s  \
# 102  Sediqullah Atal   DC    22        1    1   0  22  22.00  16  137.5     0
# 105     Kusal Mendis   GT    20        1    1   0  20  20.00  10  200.0     0
#
#      50s  4s  6s
# 102    0   0   2
# 105    0   1   2

# %%
#31 count of player in each team
df["Team"].value_counts()
# Out:
# Team
# CSK     19
# RR      17
# DC      17
# MI      16
# LSG     15
# PBKS    15
# KKR     15
# GT      14
# RCB     14
# SRH     14
# Name: count, dtype: int64

# %%
#32 average matches by team
df.groupby("Team")["Matches"].mean()
# Out:
# Team
# CSK      8.052632
# DC       8.764706
# GT      11.142857
# KKR      9.266667
# LSG     10.333333
# MI      10.312500
# PBKS    11.733333
# RCB     10.642857
# RR       9.470588
# SRH      9.714286
# Name: Matches, dtype: float64

# %%
#33 Count player by their 50s 
df.groupby("50s").size()
# Out:
# 50s
# 0    94
# 1    30
# 2    14
# 3     5
# 4     3
# 5     4
# 6     5
# 8     1
# dtype: int64

# %%
df["50s"].value_counts()
# Out:
# 50s
# 0    94
# 1    30
# 2    14
# 6     5
# 3     5
# 5     4
# 4     3
# 8     1
# Name: count, dtype: int64

# %%
#34 Average SR by Team
df.groupby("Team")["SR"].mean()
# Out:
# Team
# CSK     130.346842
# DC      119.012941
# GT      142.952857
# KKR     123.555333
# LSG     140.846667
# MI      137.221250
# PBKS    144.912667
# RCB     141.392857
# RR      137.220000
# SRH     129.773571
# Name: SR, dtype: float64

# %%
#35 Maximum SR by Team
df.groupby("Team")["SR"].max()
# Out:
# Team
# CSK     214.28
# DC      179.74
# GT      200.00
# KKR     170.83
# LSG     300.00
# MI      200.00
# PBKS    400.00
# RCB     291.66
# RR      400.00
# SRH     193.39
# Name: SR, dtype: float64

# %%
#36 Minimum HS by Team
df.groupby("Team")["HS"].min()
# Out:
# Team
# CSK       1*
# DC         1
# GT      108*
# KKR       1*
# LSG        1
# MI        1*
# PBKS      1*
# RCB        1
# RR       101
# SRH     105*
# Name: HS, dtype: object

# %%
#37 rename columns
df.rename(columns={
    "No":"Number",
    "Runs":"Runns"
})
# Out:
#            Player Name Team  Runns  Matches  Inn  Number    HS    AVG   BF  \
# 0        Sai Sudharsan   GT    759       15   15       1  108*  54.21  486
# 1    Surya Kumar Yadav   MI    717       16   16       5   73*  65.18  427
# 2          Virat Kohli  RCB    657       15   15       3   73*  54.75  454
# 3         Shubman Gill   GT    650       15   15       2   93*  50.00  417
# 4       Mitchell Marsh  LSG    627       13   13       0   117  48.23  383
# ..                 ...  ...    ...      ...  ...     ...   ...    ...  ...
# 151      Khaleel Ahmed  CSK      1       14    2       2    1*      -    2
# 152       Mohit Sharma   DC      1        8    2       1    1*   1.00    3
# 153   Donovan Ferreira   DC      1        1    1       0     1   1.00    3
# 154      Digvesh Singh  LSG      1       13    2       1     1   1.00    3
# 155     Manoj Bhandage  RCB      1        1    1       0     1   1.00    4
#
#          SR  100s  50s  4s  6s
# 0    156.17     1    6  88  21
# ...

# %%
#38 add runs percentage
df["Runs Percentage"]=df["Runs"]*0.10
df["Runs Percentage"]
# Out:
# 0      75.9
# 1      71.7
# 2      65.7
# 3      65.0
# 4      62.7
#        ...
# 151     0.1
# 152     0.1
# 153     0.1
# 154     0.1
# 155     0.1
# Name: Runs Percentage, Length: 156, dtype: float64

# %%
#39 5% of macthes
df["Percent of BF"] = df["BF"] *0.05
df["Percent of BF"]
# Out:
# 0      24.30
# 1      21.35
# 2      22.70
# 3      20.85
# 4      19.15
#        ...
# 151     0.10
# 152     0.15
# 153     0.15
# 154     0.15
# 155     0.20
# Name: Percent of BF, Length: 156, dtype: float64

# %%
#40
